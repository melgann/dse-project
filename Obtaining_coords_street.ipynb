# %%
import pandas as pd

# %%
#!pwd
# %cd ../data
# !pwd
# !ls
# Out:
# /Users/user3/Downloads/Y3:S2 NUS 2024:2025/DSE3101/data
# /Users/user3/Downloads/Y3:S2 NUS 2024:2025/DSE3101/data
# Chinook.sqlite
# CommercialRentalStatsByStreet20250303120741.csv
# CommercialRentalStatsByStreet20250303120757.csv
# CommercialRentalStatsByStreet20250303120811.csv
# CommercialRentalStatsByStreet20250303120820.csv
# Commercial_street.csv
# RoadWorks
# cars.db
# number_of_bus_stops_near_street.csv
# rental_prices.csv
# street_name_planning_area.csv
# street_name_planning_area_rental_prices.csv
# street_name_planning_area_rental_prices.numbers
# wk4_cpi2023.pdf
# wk4_nasa.txt
# wk4_pnas.pdf

# %%
df_q1 = pd.read_csv("CommercialRentalStatsByStreet20250303120741.csv")
df_q2 = pd.read_csv("CommercialRentalStatsByStreet20250303120757.csv")
df_q3 = pd.read_csv("CommercialRentalStatsByStreet20250303120811.csv")
df_q4 = pd.read_csv("CommercialRentalStatsByStreet20250303120820.csv")

df_q1.head

data_frames = [df_q1, df_q2, df_q3, df_q4]

total_ = pd.concat(data_frames) 

total = total_[total_["Median Office Rent ($ PSM per month)"] == "-"]

total.columns
# Out:
# Index(['Reference Quarter', 'Street',
#        '25th Percentile Retail Rent ($ PSM per month)',
#        'Median Retail Rent ($ PSM per month)',
#        '75th Percentile Retail Rent ($ PSM per month)',
#        '25th Percentile Office Rent ($ PSM per month)',
#        'Median Office Rent ($ PSM per month)',
#        '75th Percentile Office Rent ($ PSM per month)'],
#       dtype='object')

# %%
print(len(total))

street_names = total["Street"].unique()

print(street_names)

len(street_names)
# Out:
# 318
# ['AIRPORT BOULEVARD' 'ANG MO KIO AVENUE 3' 'BAYFRONT AVENUE' 'BEDOK ROAD'
#  'BIDADARI PARK DRIVE' 'BRAS BASAH ROAD' 'CHANGI BUSINESS PARK CENTRAL 1'
#  'CHOA CHU KANG AVENUE 4' 'CHOA CHU KANG NORTH 6'
#  'COMMONWEALTH AVENUE WEST' 'GOPENG STREET' 'GUILLEMARD ROAD'
#  'HOLLAND AVENUE' 'HOUGANG AVENUE 10' 'HOUGANG STREET 51' 'IRRAWADDY ROAD'
#  'JALAN ANAK BUKIT' 'JALAN JURONG KECHIL' 'JELEBU ROAD' 'JOO KOON CIRCLE'
#  'JURONG EAST STREET 21' 'JURONG GATEWAY ROAD' 'JURONG WEST CENTRAL 2'
#  'JURONG WEST CENTRAL 3' 'KALLANG AVENUE' 'KITCHENER ROAD' 'KOEK ROAD'
#  'LORONG 4 TOA PAYOH' 'LORONG KILAT' 'MACPHERSON ROAD' 'MARNE ROAD'
#  'NEW UPPER CHANGI ROAD' 'NORTHPOINT DRIVE' 'OCEAN WAY' 'ORCHARD TURN'
#  'PASIR PANJANG ROAD' 'PASIR RIS CLOSE' 'PETIR ROAD' 'PUNGGOL CENTRAL'
#  'QUEENSWAY' 'RAFFLES AVENUE' 'RAFFLES BOULEVARD' 'RAFFLES LINK'
#  'RIVERVALE CRESCENT' 'ROBERTSON QUAY' 'ROCHOR CANAL ROAD' 'ROCHOR ROAD'
#  'SAM LEONG ROAD' 'SEMBAWANG DRIVE' 'SEMBAWANG ROAD' 'SENGKANG SQUARE'
#  'SENGKANG WEST AVENUE' 'SERANGOON CENTRAL' 'SIMS AVENUE' 'SIMS DRIVE'
#  'SIN MING ROAD' 'SINARAN DRIVE' 'SOUTH BUONA VISTA ROAD' 'STADIUM WALK'
#  'TAI THONG CRESCENT' 'TAMPINES CENTRAL 5' 'TAN QUEE LAN STREET'
#  'TANJONG KATONG ROAD' 'TELOK KURAU ROAD' 'UNITY STREET'
#  'UPPER CIRCULAR ROAD' 'UPPER THOMSON ROAD' 'WEST COAST DRIVE'
#  'WEST COAST ROAD' 'WILKIE ROAD' 'WOODLANDS ROAD' 'YISHUN AVENUE 2'
#  'YISHUN AVENUE 9' 'YISHUN RING ROAD' 'CAVAN ROAD' 'CENTRAL BOULEVARD'
#  'COMPASSVALE BOW' 'CUSCADEN ROAD' 'JALAN MASJID' 'LORONG LIPUT'
#  'PASIR RIS CENTRAL' 'RANGOON ROAD' 'RIVER VALLEY ROAD' 'STAMFORD ROAD'
#  'TAI SENG STREET' 'TAMPINES CENTRAL 1' 'TAMPINES STREET 32'
#  'TESSENSOHN ROAD' 'VICTORIA STREET' 'YIO CHU KANG ROAD'
#  'BEDOK NORTH STREET 1' 'HOUGANG STREET 91' 'JALAN LEGUNDI'
#  'LAVENDER STREET' 'LORONG 22 GEYLANG' 'MARINE PARADE ROAD'
#  'MERCHANT ROAD' 'PENANG ROAD' 'TIONG BAHRU ROAD' 'UPPER SERANGOON ROAD'
#  'CLAYMORE DRIVE' 'CLEMENCEAU AVENUE' 'CLEMENTI AVENUE 3' 'EASTWOOD ROAD'
#  'ENG HOON STREET' 'ENGGOR STREET' 'HANDY ROAD' 'KELANTAN LANE'
#  'MAJU AVENUE' 'MOHAMED SULTAN ROAD' 'NORTH BUONA VISTA DRIVE'
#  'RACE COURSE ROAD' 'TANGLIN ROAD' 'WOODLANDS AVENUE 1' 'YISHUN CENTRAL 1']
# 115

# %%
import requests

new_df_longitude_latitude = pd.DataFrame(columns=["Street_name", "longitude", "latitude"])
#new_df_longitude_latitude.index = new_df_longitude_latitude.index + 1

for i in street_names:
    #new_add = i.replace(" ", "_")
    url = "https://www.onemap.gov.sg/api/common/elastic/search?searchVal=" + i + "&returnGeom=Y&getAddrDetails=Y&pageNum=1"   
    #url = "https://www.onemap.gov.sg/api/common/elastic/search?searchVal=AIRPORT_BOULEVARD&returnGeom=Y&getAddrDetails=Y&pageNum=1"
    headers = {"Authorization": "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..fHrfhbczzCtupYzURqDHwTqhYsEV37U5B6am7TIBH_I"}
    response = requests.get(url, headers=headers)
    data = response.json()
    #print(data)
    if data['found'] != 0: 
        latitude = data['results'][0]["LATITUDE"]
        longitude = data['results'][0]["LONGITUDE"]
        new_row = pd.DataFrame({"Street_name":[i],"longitude": [longitude], "latitude": [latitude]})
        new_df_longitude_latitude = pd.concat([new_df_longitude_latitude, new_row], ignore_index=True)
    else:
        new_row = pd.DataFrame({"Street_name":[i],"longitude": [-1], "latitude": [-1]})
        new_df_longitude_latitude = pd.concat([new_df_longitude_latitude, new_row], ignore_index=True)

    #df = pd.concat([df, new_row], ignore_index=True)

    #print(new_df_longitude_latitude)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 11
#       9 #url = "https://www.onemap.gov.sg/api/common/elastic/search?searchVal=AIRPORT_BOULEVARD&returnGeom=Y&getAddrDetails=Y&pageNum=1"
#      10 headers = {"Authorization": "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..fHrfhbczzCtupYzURqDHwTqhYsEV37U5B6am7TIBH_I"}
# ---> 11 response = requests.get(url, headers=headers)
#      12 data = response.json()
#      13 #print(data)
#
# File /opt/miniconda3/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/miniconda3/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/miniconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/miniconda3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/miniconda3/lib/python3.12/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /opt/miniconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File /opt/miniconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/miniconda3/lib/python3.12/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /opt/miniconda3/lib/python3.12/http/client.py:1423, in HTTPConnection.getresponse(self)
#    1421 try:
#    1422     try:
# -> 1423         response.begin()
#    1424     except ConnectionError:
#    1425         self.close()
#
# File /opt/miniconda3/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/miniconda3/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/miniconda3/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File /opt/miniconda3/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/miniconda3/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
new_df_longitude_latitude
# Out:
#                  Street_name         longitude          latitude
# 0          AIRPORT BOULEVARD    103.9849678239  1.34910508925639
# 1        ANG MO KIO AVENUE 3  103.856036447479  1.36930582535665
# 2            BAYFRONT AVENUE  103.858906543669  1.28162728286943
# 3                 BEDOK ROAD  103.948260304303  1.33143623119911
# 4        BIDADARI PARK DRIVE  103.872542786561  1.33877974857702
# ..                       ...               ...               ...
# 110  NORTH BUONA VISTA DRIVE  103.792154878567   1.3052419932243
# 111         RACE COURSE ROAD  103.857199382017   1.3160124626015
# 112             TANGLIN ROAD  103.816404826415  1.29474150189408
# 113       WOODLANDS AVENUE 1  103.784382967577  1.43093861934731
# 114         YISHUN CENTRAL 1  103.837286125064  1.42852396749923
#
# [115 rows x 3 columns]

# %%
new_list = []
for index, j in new_df_longitude_latitude.iterrows():

    url = "https://www.onemap.gov.sg/api/public/popapi/getPlanningarea?latitude=" + str(j[2]) + "&longitude=" + str(j[1]) + "&year=2019"
    headers = {"Authorization": "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..453puOeIN5QysyKB5hr8qqEpKhJ3BFmP9XUzyKG4ZnU"}
    response = requests.request("GET", url, headers=headers)
    data = response.json()
    area = data[0]["pln_area_n"]
    new_list.append(area)
# Out:
# /var/folders/s2/5drs3rl92nn7gpqtxrj5wys00000gr/T/ipykernel_2181/2120815520.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   url = "https://www.onemap.gov.sg/api/public/popapi/getPlanningarea?latitude=" + str(j[2]) + "&longitude=" + str(j[1]) + "&year=2019"

# %%
new_df_longitude_latitude["Planning_Area"] = new_list

# %%
new_df_longitude_latitude
# Out:
#                  Street_name         longitude          latitude  \
# 0          AIRPORT BOULEVARD    103.9849678239  1.34910508925639
# 1        ANG MO KIO AVENUE 3  103.856036447479  1.36930582535665
# 2            BAYFRONT AVENUE  103.858906543669  1.28162728286943
# 3                 BEDOK ROAD  103.948260304303  1.33143623119911
# 4        BIDADARI PARK DRIVE  103.872542786561  1.33877974857702
# ..                       ...               ...               ...
# 110  NORTH BUONA VISTA DRIVE  103.792154878567   1.3052419932243
# 111         RACE COURSE ROAD  103.857199382017   1.3160124626015
# 112             TANGLIN ROAD  103.816404826415  1.29474150189408
# 113       WOODLANDS AVENUE 1  103.784382967577  1.43093861934731
# 114         YISHUN CENTRAL 1  103.837286125064  1.42852396749923
#
#      Planning_Area
# 0           CHANGI
# 1       ANG MO KIO
# 2    DOWNTOWN CORE
# 3            BEDOK
# 4        TOA PAYOH
# ..             ...
# 110     QUEENSTOWN
# 111        KALLANG
# 112        TANGLIN
# 113      WOODLANDS
# 114         YISHUN
#
# [115 rows x 4 columns]

# %%
new_df_longitude_latitude.to_csv("street_name_planning_area.csv")

# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: numpy>=1.22 in /opt/miniconda3/lib/python3.12/site-packages (from geopandas) (1.26.4)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.10.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (5.5 kB)
# Requirement already satisfied: packaging in /opt/miniconda3/lib/python3.12/site-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.4.0 in /opt/miniconda3/lib/python3.12/site-packages (from geopandas) (2.2.3)
# Collecting pyproj>=3.3.0 (from geopandas)
#   Downloading pyproj-3.7.1.tar.gz (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.3/226.3 kB 2.6 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.0.7-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: certifi in /opt/miniconda3/lib/python3.12/site-packages (from pyogrio>=0.7.2->geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 4.0 MB/s eta 0:00:0000:0100:01
# Downloading pyogrio-0.10.0-cp312-cp312-macosx_12_0_arm64.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 4.2 MB/s eta 0:00:0000:0100:01
# Downloading shapely-2.0.7-cp312-cp312-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 4.7 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: pyproj
#   Building wheel for pyproj (pyproject.toml) ... done
#   Created wheel for pyproj: filename=pyproj-3.7.1-cp312-cp312-macosx_11_0_arm64.whl size=550482 sha256=c28840243d9b5d4d17c5cefb923e6e0f7b30b7eb9940b5720544a20e69df2f84
#   Stored in directory: /Users/user3/Library/Caches/pip/wheels/c4/72/c2/294be60784c762c3e785a7e2519c0ec43866c13ec752fb3a09
# Successfully built pyproj
# Installing collected packages: shapely, pyproj, pyogrio, geopandas
# Successfully installed geopandas-1.0.1 pyogrio-0.10.0 pyproj-3.7.1 shapely-2.0.7

# %%
#%cd ../
# %cd DSE3101/dse-project/Raw_datasets/

#!ls
import geopandas as gpd
from shapely.geometry import MultiPolygon, Point
import random

coords_start_planning_area  = gpd.read_file('district_and_planning_area.geojson')
coords_start_planning_area
# Out:
# /Users/user3/Downloads/Y3:S2 NUS 2024:2025/DSE3101/dse-project/Raw_datasets
#       district            planning_area  \
# 0         East                    Bedok
# 1      Central              Bukit Timah
# 2         West              Bukit Batok
# 3      Central              Bukit Merah
# 4        North  Central Water Catchment
# 5      Central            Downtown Core
# 6         East                   Changi
# 7         East               Changi Bay
# 8        North             Lim Chu Kang
# 9         West                 Boon Lay
# 10        West  Western Water Catchment
# 11       North                Woodlands
# 12     Central            Marine Parade
# 13     Central                   Newton
# 14  North-East    North-Eastern Islands
# 15     Central                  Orchard
# 16        East                Pasir Ris
# 17        West                  Pioneer
# 18  North-East                  Punggol
# 19     Central               Queenstown
# 20       North                Sembawang
# 21       North                  Simpang
# 22        East                 Tampines
# 23     Central                  Tanglin
# 24        West                     Tuas
# 25        West          Western Islands
# 26     Central         Southern Islands
# 27        West            Bukit Panjang
# 28     Central                   Bishan
# 29  North-East               Ang Mo Kio
# 30     Central                  Geylang
# 31     Central             Straits View
# 32        West              Jurong East
# 33  North-East                  Hougang
# 34        West              Jurong West
# 35        West            Choa Chu Kang
# 36     Central                  Kallang
# 37       North                   Mandai
# 38        West                   Tengah
# 39     Central              Marina East
# 40     Central             Marina South
# 41     Central                   Museum
# 42     Central                   Novena
# 43     Central                   Outram
# 44        East               Paya Lebar
# 45     Central             River Valley
# 46     Central                   Rochor
# 47  North-East                  Seletar
# 48  North-East                 Sengkang
# 49  North-East                Serangoon
# 50        West                 Clementi
# 51     Central                Toa Payoh
# 52     Central          Singapore River
# 53       North             Sungei Kadut
# 54       North                   Yishun
#
#                                              geometry
# 0   MULTIPOLYGON (((103.93208 1.30555, 103.93208 1...
# 1   MULTIPOLYGON (((103.79766 1.34813, 103.79806 1...
# 2   MULTIPOLYGON (((103.76408 1.37001, 103.76444 1...
# 3   MULTIPOLYGON (((103.82362 1.26018, 103.82362 1...
# 4   MULTIPOLYGON (((103.80702 1.41126, 103.80754 1...
# 5   MULTIPOLYGON (((103.86655 1.30386, 103.86696 1...
# 6   MULTIPOLYGON (((103.98236 1.39356, 103.98242 1...
# 7   MULTIPOLYGON (((104.03143 1.35741, 104.03154 1...
# 8   MULTIPOLYGON (((103.72246 1.45116, 103.72426 1...
# 9   MULTIPOLYGON (((103.72042 1.32824, 103.72003 1...
# 10  MULTIPOLYGON (((103.69302 1.43367, 103.69324 1...
# 11  MULTIPOLYGON (((103.79281 1.46048, 103.79282 1...
# 12  MULTIPOLYGON (((103.90806 1.30982, 103.90822 1...
# 13  MULTIPOLYGON (((103.84577 1.30984, 103.84686 1...
# 14  MULTIPOLYGON (((104.05408 1.43231, 104.05431 1...
# 15  MULTIPOLYGON (((103.83533 1.30806, 103.83538 1...
# 16  MULTIPOLYGON (((103.93478 1.40099, 103.93625 1...
# 17  MULTIPOLYGON (((103.68611 1.32777, 103.68661 1...
# 18  MULTIPOLYGON (((103.91082 1.42147, 103.91084 1...
# 19  MULTIPOLYGON (((103.7846 1.31109, 103.78475 1....
# 20  MULTIPOLYGON (((103.81732 1.47077, 103.81732 1...
# 21  MULTIPOLYGON (((103.8635 1.43433, 103.86361 1....
# 22  MULTIPOLYGON (((103.97066 1.34146, 103.97067 1...
# 23  MULTIPOLYGON (((103.82761 1.30728, 103.82746 1...
# 24  MULTIPOLYGON (((103.6476 1.2395, 103.64758 1.2...
# 25  MULTIPOLYGON (((103.71253 1.29162, 103.71258 1...
# 26  MULTIPOLYGON (((103.82325 1.25748, 103.8233 1....
# 27  MULTIPOLYGON (((103.77445 1.39029, 103.77499 1...
# 28  MULTIPOLYGON (((103.84297 1.36429, 103.84297 1...
# 29  MULTIPOLYGON (((103.85721 1.39654, 103.85731 1...
# 30  MULTIPOLYGON (((103.90179 1.30974, 103.9015 1....
# 31  MULTIPOLYGON (((103.86269 1.26976, 103.85997 1...
# 32  MULTIPOLYGON (((103.71188 1.29961, 103.71187 1...
# 33  MULTIPOLYGON (((103.88152 1.38774, 103.88269 1...
# 34  MULTIPOLYGON (((103.72813 1.34888, 103.72816 1...
# 35  MULTIPOLYGON (((103.7466 1.40541, 103.74691 1....
# 36  MULTIPOLYGON (((103.86277 1.3303, 103.86302 1....
# 37  MULTIPOLYGON (((103.82439 1.43506, 103.82443 1...
# 38  MULTIPOLYGON (((103.73756 1.3465, 103.73726 1....
# 39  MULTIPOLYGON (((103.88025 1.28386, 103.88024 1...
# 40  MULTIPOLYGON (((103.86473 1.28885, 103.86909 1...
# 41  MULTIPOLYGON (((103.84575 1.30092, 103.8464 1....
# 42  MULTIPOLYGON (((103.83599 1.34168, 103.83704 1...
# 43  MULTIPOLYGON (((103.84313 1.28778, 103.84338 1...
# 44  MULTIPOLYGON (((103.91854 1.38129, 103.91886 1...
# 45  MULTIPOLYGON (((103.83059 1.304, 103.83074 1.3...
# 46  MULTIPOLYGON (((103.85617 1.30908, 103.85685 1...
# 47  MULTIPOLYGON (((103.89715 1.41502, 103.89742 1...
# 48  MULTIPOLYGON (((103.88848 1.40105, 103.88996 1...
# 49  MULTIPOLYGON (((103.88239 1.34452, 103.88272 1...
# 50  MULTIPOLYGON (((103.76707 1.3312, 103.76708 1....
# 51  MULTIPOLYGON (((103.84477 1.34394, 103.84508 1...
# 52  MULTIPOLYGON (((103.8341 1.29248, 103.8341 1.2...
# 53  MULTIPOLYGON (((103.75819 1.44338, 103.75832 1...
# 54  MULTIPOLYGON (((103.85955 1.42552, 103.86197 1...

# %%
# Example: Load a GeoJSON file with MultiPolygons and a 'name' column
gdf = gpd.read_file('district_and_planning_area.geojson')

# Ensure the geometry column is set
gdf = gdf.set_geometry('geometry')

# Function to calculate centroids and create a table
def create_centroid_table(gdf):
    centroids = []
    
    for index, row in gdf.iterrows():
        name = row['planning_area']  # Replace 'name' with the actual column name for the polygon name
        multipolygon = row['geometry']  # Get the MultiPolygon geometry
        
        # Calculate the centroid
        centroid = multipolygon.centroid
        
        # Extract latitude and longitude
        longitude = centroid.x
        latitude = centroid.y
        
        # Append to the list
        centroids.append({
            'name': name,
            'latitude': latitude,
            'longitude': longitude
        })
    
    # Convert the list to a pandas DataFrame
    centroid_table = pd.DataFrame(centroids)
    return centroid_table

# Create the centroid table
centroid_table = create_centroid_table(gdf)

# Display the table
print(centroid_table)
# Out:
#                        name  latitude   longitude
# 0                     Bedok  1.324047  103.928409
# 1               Bukit Timah  1.329997  103.790700
# 2               Bukit Batok  1.355658  103.754732
# 3               Bukit Merah  1.275489  103.823135
# 4   Central Water Catchment  1.376651  103.801196
# 5             Downtown Core  1.286789  103.855497
# 6                    Changi  1.350316  103.997820
# 7                Changi Bay  1.327422  104.026357
# 8              Lim Chu Kang  1.430643  103.719285
# 9                  Boon Lay  1.314787  103.702217
# 10  Western Water Catchment  1.382130  103.689730
# 11                Woodlands  1.440681  103.787705
# 12            Marine Parade  1.300228  103.896272
# 13                   Newton  1.308660  103.838078
# 14    North-Eastern Islands  1.401641  104.034823
# 15                  Orchard  1.303807  103.833580
# 16                Pasir Ris  1.378618  103.948287
# 17                  Pioneer  1.312585  103.672987
# 18                  Punggol  1.405364  103.910046
# 19               Queenstown  1.289083  103.784568
# 20                Sembawang  1.455747  103.818828
# 21                  Simpang  1.444085  103.852919
# 22                 Tampines  1.343786  103.954029
# 23                  Tanglin  1.308375  103.817595
# 24                     Tuas  1.280235  103.633103
# 25          Western Islands  1.249549  103.709028
# 26         Southern Islands  1.242999  103.835849
# 27            Bukit Panjang  1.366822  103.772998
# 28                   Bishan  1.354955  103.840436
# 29               Ang Mo Kio  1.380094  103.842098
# 30                  Geylang  1.320896  103.889523
# 31             Straits View  1.271252  103.858773
# 32              Jurong East  1.320442  103.734797
# 33                  Hougang  1.363638  103.889800
# 34              Jurong West  1.341612  103.704902
# 35            Choa Chu Kang  1.385556  103.747191
# 36                  Kallang  1.311125  103.866544
# 37                   Mandai  1.423623  103.802460
# 38                   Tengah  1.363853  103.728746
# 39              Marina East  1.288517  103.872352
# 40             Marina South  1.280531  103.865628
# 41                   Museum  1.295916  103.846717
# 42                   Novena  1.326984  103.835309
# 43                   Outram  1.282859  103.842061
# 44               Paya Lebar  1.359398  103.914779
# 45             River Valley  1.298046  103.833978
# 46                   Rochor  1.304139  103.853284
# 47                  Seletar  1.414340  103.877099
# 48                 Sengkang  1.391279  103.887708
# 49                Serangoon  1.365202  103.867818
# 50                 Clementi  1.317592  103.760751
# 51                Toa Payoh  1.336684  103.861026
# 52          Singapore River  1.290115  103.841210
# 53             Sungei Kadut  1.418126  103.757461
# 54                   Yishun  1.415039  103.837118

# %%
# !ls
# %cd ../cleaned_datasets
# Out:
# bus_stops.csv                       rental_prices.csv
# number_of_bus_stops_near_street.csv street_name_planning_area.csv
# number_of_mrt_near_street.csv       streets_malls_school_pop.csv
# /Users/user3/Downloads/Y3:S2 NUS 2024:2025/DSE3101/dse-project/Cleaned_Datasets

# %%
ending_coordinates = pd.read_csv("street_name_planning_area.csv")
ending_coordinates
# Out:
#      Unnamed: 0          Street_name   longitude  latitude  Planning_Area
# 0             0    AIRPORT BOULEVARD  103.984968  1.349105         CHANGI
# 1             1        ALBERT STREET  103.851354  1.303687         ROCHOR
# 2             2       ALEXANDRA ROAD  103.815285  1.291537    BUKIT MERAH
# 3             3  ANG MO KIO AVENUE 3  103.856036  1.369306     ANG MO KIO
# 4             4           ANSON ROAD  103.845525  1.274622  DOWNTOWN CORE
# ..          ...                  ...         ...       ...            ...
# 163         163    YIO CHU KANG ROAD  103.873959  1.361020        HOUGANG
# 164         164      YISHUN AVENUE 2  103.833188  1.416244         YISHUN
# 165         165      YISHUN AVENUE 9  103.839848  1.431624         YISHUN
# 166         166     YISHUN CENTRAL 1  103.837286  1.428524         YISHUN
# 167         167     YISHUN RING ROAD  103.828893  1.431370         YISHUN
#
# [168 rows x 5 columns]

# %%
import requests


import requests
import pandas as pd

new_df_with_time = pd.DataFrame(columns=["Street_name", "Planning_area", "Time_taken"])


# Example: centroid_table and ending_coordinates are pandas DataFrames
# centroid_table has columns: ['name', 'latitude', 'longitude']
# ending_coordinates has columns: ['name', 'latitude', 'longitude']

# Iterate over rows in centroid_table (skip the header row)
for _, start_row in centroid_table[1:].iterrows():
    starting_latitude = start_row['latitude']
    print(starting_latitude)
    starting_longitude = start_row['longitude']
    print(starting_longitude)
    
    # Iterate over rows in ending_coordinates (skip the header row)
    for _, end_row in ending_coordinates[1:].iterrows():
        ending_latitude = end_row['latitude']
        print(ending_latitude)
        ending_longitude = end_row['longitude']
        
        # Construct the URL
        #url = f"https://www.onemap.gov.sg/api/public/routingsvc/route?start={starting_latitude}%2C{starting_longitude}&end={ending_latitude}%2C{ending_longitude}&routeType=pt&date=03-19-2023&time=07%3A35%3A00&mode=TRANSIT&maxWalkDistance=1000&numItineraries=1"
        #url = f"https://www.onemap.gov.sg/api/public/routingsvc/route?start={starting_latitude}%2C{starting_longitude}&end={ending_latitude}%2C{ending_longitude}&routeType=pt&date=03-19-2023&time=07%3A35%3A12&mode=BUS&maxWalkDistance=1&numItineraries=1"
        url = "https://www.onemap.gov.sg/api/public/routingsvc/route?start=1.320981%2C103.844150&end=1.326762%2C103.8559&routeType=pt&date=08-13-2023&time=07%3A35%3A00&mode=TRANSIT&maxWalkDistance=10&numItineraries=3"

        # Set headers
        headers = {
            "Authorization": "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..QHWTAnjKcfFzWNKiAOxH0gc3kgsWVz9Wp4c4G49kvM0"
        }
        
        # Make the API request
        response = requests.get(url, headers=headers)
        data = response.json()
        
        # Print the response data
        print(data)

        if 'message' not in data:
            time = data['plan']['itineraries'][0]['duration']
            planning_area_start = start_row['name']
            street_name_end = end_row['Street_name']
            new_row = pd.DataFrame({"Street_name":[street_name_end], "Planning_area": [planning_area_start], "Time_taken": [time]})
            new_df_with_time = pd.concat([new_df_with_time, new_row], ignore_index=True)
            #print(new_row)

new_df_with_time
        
    #else:
        #new_row = pd.DataFrame({"Street_name":[i],"longitude": [-1], "latitude": [-1]})
        #new_df_longitude_latitude = pd.concat([new_df_longitude_latitude, new_row], ignore_index=True)
# Out:
# 1.3299968034818934
# 103.79069954585295
# 1.30368668240573
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.29153654792628
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.36930582535665
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.27462245416877
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.32218489201971
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.28549647937914
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.28162728286943
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.29791640665876
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.32588491763491
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.33143623119911
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.30015021985465
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.33877974857702
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.29609874343828
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.30376144472777
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.35349310900464
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.31092116730954
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.28012724159922
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.27661641863168
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.33686348295857
# ...
# 1.34071468946651
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.30977661688661
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.3399379140725
# {'requestParameters': {'mode': 'WALK', 'date': '08-13-2023', 'arriveBy': 'false', 'walkReluctance': '10', 'showIntermediateStops': 'true', 'fromPlace': '1.320981,103.84415', 'transferPenalty': '7200', 'toPlace': '1.326762,103.8559', 'maxWalkDistance': '1000', 'time': '7:35 AM', 'maxTransfers': '3', 'numItineraries': '3'}, 'plan': {'date': 1691883300000, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'vertexType': 'NORMAL'}, 'itineraries': [{'duration': 1873, 'startTime': 1691883300000, 'endTime': 1691885173000, 'walkTime': 1873, 'transitTime': 0, 'waitingTime': 0, 'walkDistance': 1969.36, 'walkLimitExceeded': False, 'generalizedCost': 16130, 'elevationLost': 0, 'elevationGained': 0, 'transfers': 0, 'fare': '0.00', 'legs': [{'startTime': 1691883300000, 'endTime': 1691885173000, 'departureDelay': 0, 'arrivalDelay': 0, 'realTime': False, 'distance': 1969.36, 'generalizedCost': 16130, 'pathway': False, 'mode': 'WALK', 'transitLeg': False, 'route': '', 'agencyTimeZoneOffset': 28800000, 'interlineWithPreviousLeg': False, 'from': {'name': 'Origin', 'lon': 103.84415, 'lat': 1.320981, 'departure': 1691883300000, 'vertexType': 'NORMAL'}, 'to': {'name': 'Destination', 'lon': 103.8559, 'lat': 1.326762, 'arrival': 1691885173000, 'vertexType': 'NORMAL'}, 'legGeometry': {'points': 's~`GmayxRa@a@VSDE_@[CBIHQHG@E?E?ICIEgAcAIMqA}@QICCMGWMMEUKOEOEcAYAC?IRu@J]BMNe@Nm@DCAEWIC?MAUGiAg@?ADG@A@EYKGE?WPa@DKd@kADKLY@CACBQHCr@gB@KGSGKEE]OICIEOMKGYM[MGCGCK?GK?EACEEIGGIGGIIGGIICCCCCEOOGGIIMMIIUWMQSSLG@ARWLQXYECHGLKBIh@g@LM\\WRQPMNMNKZUAC][AA@CEKQOCCGEYWIGECCCMKGGMIECECIIGGCCEEKGa@_@MIq@i@OMKGGGKIGEOKEM?CGGQMAAAAC???OM??YWC?OOGGCAMKCACC@AFI@AECCEACCAA?CCa@[UOIGUQCCKK[UQOGG?G?ET[QOCCEAIIMIFIl@y@MI', 'length': 186}, 'steps': [{'distance': 1969.36, 'relativeDirection': 'DEPART', 'streetName': 'path', 'absoluteDirection': 'NORTHEAST', 'stayOn': False, 'area': False, 'bogusName': True, 'lon': 103.8442314, 'lat': 1.3209015, 'elevation': '', 'walkingBike': False}], 'rentedBike': False, 'walkingBike': False, 'duration': 1873}], 'tooSloped': False, 'arrivedAtDestinationWithRentedBicycle': False}]}, 'debugOutput': {'precalculationTime': 12441, 'directStreetRouterTime': 7270419, 'transitRouterTime': 1803954, 'filteringTime': 69168, 'renderingTime': 49179, 'totalTime': 9212404, 'transitRouterTimes': {'tripPatternFilterTime': 0, 'accessEgressTime': 0, 'raptorSearchTime': 0, 'itineraryCreationTime': 0}}, 'elevationMetadata': {'ellipsoidToGeoidDifference': 7.471744694591218, 'geoidElevation': False}}
# 1.44130521573477
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 38
#      33 headers = {
#      34     "Authorization": "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..QHWTAnjKcfFzWNKiAOxH0gc3kgsWVz9Wp4c4G49kvM0"
#      35 }
#      37 # Make the API request
# ---> 38 response = requests.get(url, headers=headers)
#      39 data = response.json()
#      41 # Print the response data
#
# File /opt/miniconda3/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/miniconda3/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/miniconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/miniconda3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/miniconda3/lib/python3.12/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /opt/miniconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File /opt/miniconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     464 try:
#     465     # Trigger any extra validation we need to do.
#     466     try:
# --> 467         self._validate_conn(conn)
#     468     except (SocketTimeout, BaseSSLError) as e:
#     469         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /opt/miniconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:1096, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 # Force connect early to allow us to validate the connection.
#    1095 if conn.is_closed:
# -> 1096     conn.connect()
#    1098 if not conn.is_verified:
#    1099     warnings.warn(
#    1100         (
#    1101             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1106         InsecureRequestWarning,
#    1107     )
#
# File /opt/miniconda3/lib/python3.12/site-packages/urllib3/connection.py:642, in HTTPSConnection.connect(self)
#     633 if is_time_off:
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#     661 self.is_verified = sock_and_verified.is_verified
#
# File /opt/miniconda3/lib/python3.12/site-packages/urllib3/connection.py:782, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     779     if is_ipaddress(normalized):
#     780         server_hostname = normalized
# --> 782 ssl_sock = ssl_wrap_socket(
#     783     sock=sock,
#     784     keyfile=key_file,
#     785     certfile=cert_file,
#     786     key_password=key_password,
#     787     ca_certs=ca_certs,
#     788     ca_cert_dir=ca_cert_dir,
#     789     ca_cert_data=ca_cert_data,
#     790     server_hostname=server_hostname,
#     791     ssl_context=context,
#     792     tls_in_tls=tls_in_tls,
#     793 )
#     795 try:
#     796     if assert_fingerprint:
#
# File /opt/miniconda3/lib/python3.12/site-packages/urllib3/util/ssl_.py:445, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     443 if ca_certs or ca_cert_dir or ca_cert_data:
#     444     try:
# --> 445         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     446     except OSError as e:
#     447         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %%
new_df_with_time
# Out:
#               Street_name Planning_area Time_taken
# 0           ALBERT STREET   Bukit Timah       7979
# 1          ALEXANDRA ROAD   Bukit Timah       6145
# 2     ANG MO KIO AVENUE 3   Bukit Timah      11495
# 3              ANSON ROAD   Bukit Timah      10037
# 4          BALESTIER ROAD   Bukit Timah       7668
# ...                   ...           ...        ...
# 2193    ROCHOR CANAL ROAD   Jurong East      13954
# 2194          ROCHOR ROAD   Jurong East      14062
# 2195          SCOTTS ROAD   Jurong East      11609
# 2196         SELEGIE ROAD   Jurong East      13567
# 2197          SHENTON WAY   Jurong East      13836
#
# [2198 rows x 3 columns]

# %%
import requests
    
url = "https://www.onemap.gov.sg/api/public/routingsvc/route?start=1.320981%2C103.844150&end=1.326762%2C103.8559&routeType=pt&date=08-13-2023&time=07%3A35%3A00&mode=TRANSIT&maxWalkDistance=1000&numItineraries=3"
    
headers = {"Authorization": "**********************"}
    
response = requests.request("GET", url, headers=headers)
    
print(response.text)
